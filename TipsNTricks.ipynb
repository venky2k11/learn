# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Send Email and SMS:

# %%
# import smtplib
# from email.message import EmailMessage

# def email_alert(subject, body,to):
#     msg = EmailMessage()
#     msg.set_content(body)
#     msg['subject'] = subject
#     msg['to'] = to
#     msg['from'] = 'bvrlearningfacebook@gmail.com'
    
#     user = 'bvrlearningfacebook@gmail.com'
#     password = 'rwbattmudwggkrdi' # Google Account->Security->2step veri->App Password
    
#     server = smtplib.SMTP("smtp.gmail.com",587)
#     server.starttls()
#     server.login(user,password)
#     server.send_message(msg)
#     server.quit()

# # Email
# email_alert('Hello', 'Hi, Good evening','venky2k11@gmail.com')
# # SMS
# email_alert('Hello', 'Hi 61 no0, Good evening','+61434837617@sms.tim.telstra.com')

# %% [markdown]
# # Data visualization:

# %% [markdown]
# ## Chart Type selection:

# %%
from IPython.display import Image
Image("data/Abelas-Chart-Selection-Diagram.jpg")

# %% [markdown]
# # DataFrame operations:

# %% [markdown]
# ## Create DataFrame with X rows and Y columns

# %%
import pandas as pd
n_rows = 10000
n_cols = 1000

# %%
df = pd.DataFrame(np.random.randint(0,100,size=(n_rows,n_cols)), columns=['col%d' % i for i in range(n_cols)])
df.head()
# Out:
#    col0  col1  col2  col3  col4  col5  col6  col7  col8  col9  ...  col990  \
# 0    44    34    19    30    36    60    45    72    84    97  ...      46
# 1    80    87    76    22    32     2    14    13    22    95  ...      43
# 2    13    31    73    68    81    27    71    61    83    94  ...      46
# 3    62    15    88    16    58    28    68    38    14    69  ...      29
# 4    84     2    64    39     0    22    94    49    84    84  ...      35
#
#    col991  col992  col993  col994  col995  col996  col997  col998  col999
# 0      76      39      50      54      81      53      19      13      88
# 1      92      37      19      47      62      27      47      51      49
# 2      19      65       5      55      40      59      73      71      86
# 3      88      69      67      19       7      22      40      55       6
# 4      81      84       8      90      61      69       1      61      91
#
# [5 rows x 1000 columns]

# %% [markdown]
# ## Check DataFrame memory usage:

# %%
import pandas as pd 
n_rows = 10000
n_cols = 1000
df = pd.DataFrame(np.random.randint(0,100,size=(n_rows,n_cols)), columns=['col%d' % i for i in range(n_cols)])
df.head()
# Out:
#    col0  col1  col2  col3  col4  col5  col6  col7  col8  col9  ...  col990  \
# 0     1    67    79    92    19    32    47    26     6    80  ...       9
# 1    28    46    78    69    40    53    36    16    46    91  ...      23
# 2    77    17    42    85    68    82    55    63    44    36  ...      21
# 3    49    20    72    36    78    58    91    67    12    67  ...      17
# 4    20    99    87    83    97    27    15    99    46     0  ...      14
#
#    col991  col992  col993  col994  col995  col996  col997  col998  col999
# 0      86      90      72      16      36      88       5      64      61
# 1       1      99      29      43       2      74      69      30      63
# 2      26      38      23      29      69      91       1      88      59
# 3      58      92      23      58      63      59      63      27      80
# 4      15      24      97       3      94      79      77      40       4
#
# [5 rows x 1000 columns]

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Columns: 1000 entries, col0 to col999
# dtypes: int32(1000)
# memory usage: 38.1 MB

# %% [markdown]
# ## Read JSON

# %%
import pandas as pd

# %%
with open('data/1.json') as f:
    d = json.load(f)
    data = pd.DataFrame(d)
data.head()

# %% [markdown]
# ## Read CSV

# %%
import pandas as pd
parse_dates = ['DoB', 'dateadmittedicu', 'dateleavingicu', 'finaloutcomedate','hospitaladmissiondate','infectionswabdate','estimateddate','labtestdate']
data = pd.read_csv('data/SynthVentDataset_Test.csv',date_parser= pd.to_datetime,index_col=False,parse_dates=parse_dates)
data.head()

# %% [markdown]
# ### Reading Public CSV file in GitHub

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv'
df = pd.read_csv(url)
df.head()

# %% [markdown]
# ### Reading Private CSV file in GitHub

# %%
import requests
import pandas as pd 
from io import StringIO

url = 'https://raw.githubusercontent.com/venky2k11/test/master/time_series_covid19_confirmed_global.csv?token=APTGCZLM325OO7Z5INTMJ626ZZIOC'
bytes_data = requests.get(url)
bytes_data

# %% [markdown]
# ## Write DataFrame to JSON

# %%
import pandas as pd
parse_dates = ['DoB', 'dateadmittedicu', 'dateleavingicu', 'finaloutcomedate','hospitaladmissiondate','infectionswabdate','estimateddate','labtestdate']
data = pd.read_csv('data/SynthVentDataset_Test.csv',date_parser= pd.to_datetime,index_col=False,parse_dates=parse_dates)
x = data.to_json()
x

# %% [markdown]
# ## Rename DataFrame Column

# %%
import pandas as pd
parse_dates = ['DoB', 'dateadmittedicu', 'dateleavingicu', 'finaloutcomedate','hospitaladmissiondate','infectionswabdate','estimateddate','labtestdate']
data = pd.read_csv('data/SynthVentDataset_Test.csv',date_parser= pd.to_datetime,index_col=False,parse_dates=parse_dates)
data.head()

# %%
data.rename(columns = {'DoB':'Date of Birth'}, inplace = True)
data.head()

# %% [markdown]
# ## Replace Column values in DataFrame

# %%
import pandas as pd
raw_data = {'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'], 
        'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'], 
        'age': [42, 52, 36, 24, 73], 
        'preTestScore': [-999, -999, -999, 2, 1],
        'postTestScore': [2, 2, -999, 2, -999]}
df = pd.DataFrame(raw_data, columns = ['first_name', 'last_name', 'age', 'preTestScore', 'postTestScore'])
df

# %%
x = {-999: "Yes", 2:"No"}
df = df.replace(x)
df

# %%
y= {"No":2}
df['preTestScore'] = df['preTestScore'].replace(y)
df

# %% [markdown]
# ## Replace Blank values with NaN

# %%
import pandas as pd
raw_data = {'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'], 
        'last_name': ['Miller', 'Jacobson', '', 'Milner', ''], 
        'age': [42, 52, 36, 24, 73], 
        'preTestScore': [-999, -999, -999, 2, 1],
        'postTestScore': [2, 2, -999, 2, -999]}
df = pd.DataFrame(raw_data, columns = ['first_name', 'last_name', 'age', 'preTestScore', 'postTestScore'])
df

# %%
import numpy as np
df.replace(r'^\s*$', np.nan, regex=True,inplace=True)
df

# %% [markdown]
# ## Replace NaN with a default value

# %%
import pandas as pd
from datetime import *
raw_data = {'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'], 
        'last_name': ['Miller', 'Jacobson', '', 'Milner', ''], 
        'DoB': ['1982/07/28', '', '1982-07-28', '', '29/07/1982'], 
        'preTestScore': [-999, -999, -999, 2, 1],
        'postTestScore': [2, 2, -999, 2, -999]}
df = pd.DataFrame(raw_data, columns = ['first_name', 'last_name', 'DoB', 'preTestScore', 'postTestScore'])
df.replace(r'^\s*$', np.nan, regex=True,inplace=True)
df

# %%
df['DoB'].fillna(value=pd.to_datetime('1/1/1900'), inplace=True)
df

# %%
df['DoB'] = pd.to_datetime(df['DoB']).apply(lambda x: x.date())
df

# %% [markdown]
# ## Access specific row value in DataFrame

# %%
df.iloc[0]['first_name']

# %% [markdown]
# ## Merge 2 Dataframes on a Column

# %%
import pandas as pd

# %%
df1 = pd.read_csv('data/ref.csv')
df2 = pd.read_csv('data/re.csv', header=None, names=['caseid','prediction'],skiprows=1 )

# %%
df1 = df1[['caseid','DoB','ageyear']]
df1.head()

# %%
df2.head()

# %%
df_merge_col = pd.merge(df1, df2, on='caseid')
df_merge_col

# %% [markdown]
# ## Compute a Column using another Column

# %%
import pandas as pd
from datetime import *
raw_data = {'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'], 
        'last_name': ['Miller', 'Jacobson', '', 'Milner', ''], 
        'DoB': ['1982/07/28', '1982-07-28', '1982-07-28', '1982-07-28', '29/07/1982'], 
        'preTestScore': [-999, -999, -999, 2, 1],
        'postTestScore': [2, 3, -999, 2, -999]}
df = pd.DataFrame(raw_data, columns = ['first_name', 'last_name', 'DoB', 'preTestScore', 'postTestScore'])
df

# %%
df['isscore2'] = np.where((df['postTestScore'] == 2) | (df['postTestScore'] == 3),'1',0)
df

# %% [markdown]
# ## Convert Columns to Rows

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv'
data = pd.read_csv(url)
data.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  5/28/20  5/29/20  5/30/20  5/31/20  6/1/20  \
# 0        0        0        0  ...    13036    13659    14525    15205   15750
# 1        0        0        0  ...     1076     1099     1122     1137    1143
# 2        0        0        0  ...     8997     9134     9267     9394    9513
# 3        0        0        0  ...      763      764      764      764     765
# 4        0        0        0  ...       74       81       84       86      86
#
# ...

# %%
df1 = (data.set_index(['Province/State', 'Country/Region', 'Lat', 'Long'])
         .stack()
         .reset_index(name='Value')
         .rename(columns={'level_4':'Date'}))
df1.sort_values(by='Date',inplace=True)
df1.head()
# Out:
#       Province/State Country/Region      Lat     Long     Date  Value
# 0                NaN    Afghanistan  33.0000  65.0000  1/22/20      0
# 19865            NaN     Kyrgyzstan  41.2044  74.7661  1/22/20      0
# 20002            NaN         Latvia  56.8796  24.6032  1/22/20      0
# 20139            NaN        Lebanon  33.8547  35.8623  1/22/20      0
# 20276            NaN        Liberia   6.4281  -9.4295  1/22/20      0

# %% [markdown]
# ## Compute AGE using DATE field

# %%
import pandas as pd
from datetime import *
raw_data = {'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'], 
        'last_name': ['Miller', 'Jacobson', '', 'Milner', ''], 
        'DoB': ['1982/07/28', '1982-07-28', '1982-07-28', '1982-07-28', '29/07/1982'], 
        'preTestScore': [-999, -999, -999, 2, 1],
        'postTestScore': [2, 2, -999, 2, -999]}
df = pd.DataFrame(raw_data, columns = ['first_name', 'last_name', 'DoB', 'preTestScore', 'postTestScore'])
df

# %%
days_in_year = 365.2425
df['DoB'] = pd.to_datetime(df['DoB']).apply(lambda x: x.date())
df['Age'] = df['DoB'].apply(lambda x: int(((date.today() - x).days / days_in_year)))
df

# %% [markdown]
# ## Drop column if it has only one unique value

# %%
import pandas as pd
from datetime import *
raw_data = {'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'], 
        'last_name': ['Miller', 'Jacobson', '', 'Milner', ''], 
        'DoB': ['1982/07/28', '', '1982-07-28', '', '29/07/1982'], 
        'preTestScore': [-999, -999, -999, 2, 1],
        'postTestScore': [2, 2, -999, 2, -999],
        'City':['Canberra','Canberra','Canberra','Canberra','Canberra']}
df = pd.DataFrame(raw_data, columns = ['first_name', 'last_name', 'DoB', 'preTestScore', 'postTestScore','City'])
df

# %%
df.drop(df[df.columns[df.nunique() <= 1]].columns, axis=1,inplace=True)
df

# %% [markdown]
# ## Drop column if all values are null

# %%
import pandas as pd
from datetime import *
raw_data = {'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'], 
        'last_name': ['Miller', 'Jacobson', '', 'Milner', ''], 
        'DoB': ['1982/07/28', '', '1982-07-28', '', '29/07/1982'], 
        'preTestScore': [-999, -999, -999, 2, 1],
        'postTestScore': [2, 2, -999, 2, -999],
        'City':['','','','','']}
df = pd.DataFrame(raw_data, columns = ['first_name', 'last_name', 'DoB', 'preTestScore', 'postTestScore','City'])
df.replace(r'^\s*$', np.nan, regex=True,inplace=True)
df

# %%
df.drop(df.columns[df.isnull().all()], axis=1,inplace=True)
df

# %% [markdown]
# ## Convert into Bins

# %%
import pandas as pd
parse_dates = ['DoB', 'dateadmittedicu', 'dateleavingicu', 'finaloutcomedate','hospitaladmissiondate','infectionswabdate','estimateddate','labtestdate']
data = pd.read_csv('data/SynthVentDataset_Test.csv',date_parser= pd.to_datetime,index_col=False,parse_dates=parse_dates)
days_in_year = 365.2425
data.replace(r'^\s*$', np.nan, regex=True,inplace=True)
data['DoB'] = pd.to_datetime(data['DoB']).apply(lambda x: x.date())
data['Age'] = data['DoB'].apply(lambda x: int(((date.today() - x).days / days_in_year)))

bins = [0,24,np.inf]
names = ['LE_24', 'GE_25']
data['bmiRange'] = pd.cut(data['obesitybmi'], bins, labels=names)

bins = [0,30,50,75,np.inf]
names = ['LE_30','31_50','51_75','75+']
data['AgeRange'] = pd.cut(data['Age'], bins, labels=names)

data[['caseid','DoB','Age','AgeRange','obesitybmi','bmiRange']].head()

# %% [markdown]
# ## Convert DataFrame to List

# %%
import pandas as pd
from datetime import *
raw_data = {'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'], 
        'last_name': ['Miller', 'Jacobson', '', 'Milner', ''], 
        'DoB': ['1982/07/28', '', '1982-07-28', '', '29/07/1982'], 
        'preTestScore': [-999, -999, -999, 2, 1],
        'postTestScore': [2, 2, -999, 2, -999],
        'City':['Canberra','Canberra','Canberra','Canberra','Canberra']}
df = pd.DataFrame(raw_data, columns = ['first_name', 'last_name', 'DoB', 'preTestScore', 'postTestScore','City'])
df

# %%
newlist = df.values.flatten()
newlist

# %% [markdown]
# ## Convert Datetime column to Date

# %%
import pandas as pd
from datetime import *
raw_data = {'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'], 
        'last_name': ['Miller', 'Jacobson', '', 'Milner', ''], 
        'DoB': ['1982/07/28', '', '1982-07-28', '', '29/07/1982'], 
        'preTestScore': [-999, -999, -999, 2, 1],
        'postTestScore': [2, 2, -999, 2, -999]}
df = pd.DataFrame(raw_data, columns = ['first_name', 'last_name', 'DoB', 'preTestScore', 'postTestScore'])
df.replace(r'^\s*$', np.nan, regex=True,inplace=True)
df['DoB'].fillna(value=pd.to_datetime('1/1/1900'), inplace=True)
df.dtypes

# %% [markdown]
# Notice that Date dtype is "Object"

# %%
df

# %%
df['DoB'] = pd.to_datetime(df['DoB']).apply(lambda x: x.date())
df

# %%
df.dtypes

# %% [markdown]
# ## Convert Date from "Object" to "datetime64[ns]"

# %%
import pandas as pd
from datetime import *
raw_data = {'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'], 
        'last_name': ['Miller', 'Jacobson', '', 'Milner', ''], 
        'DoB': ['1982/07/28', '', '1982-07-28', '', '29/07/1982'], 
        'preTestScore': [-999, -999, -999, 2, 1],
        'postTestScore': [2, 2, -999, 2, -999]}
df = pd.DataFrame(raw_data, columns = ['first_name', 'last_name', 'DoB', 'preTestScore', 'postTestScore'])
df.replace(r'^\s*$', np.nan, regex=True,inplace=True)
df['DoB'].fillna(value=pd.to_datetime('1/1/1900'), inplace=True)
df.dtypes

# %%
df['DoB'] = pd.to_datetime(df['DoB']).apply(lambda x: x.date())
# df['DoB'] = pd.to_datetime(df.DoB,format='%d-%m-%Y %H:%M')
df['DoB'] = pd.to_datetime(df.DoB,format='%Y-%m-%d')
df.dtypes

# %% [markdown]
# ## Convert Date to Day, Month, Year, Day of Week

# %%
import pandas as pd
from datetime import *
raw_data = {'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'], 
        'last_name': ['Miller', 'Jacobson', '', 'Milner', ''], 
        'DoB': ['1982/07/28', '', '1982-07-28', '', '29/07/1982'], 
        'preTestScore': [-999, -999, -999, 2, 1],
        'postTestScore': [2, 2, -999, 2, -999]}
df = pd.DataFrame(raw_data, columns = ['first_name', 'last_name', 'DoB', 'preTestScore', 'postTestScore'])
df.replace(r'^\s*$', np.nan, regex=True,inplace=True)
df['DoB'].fillna(value=pd.to_datetime('1/1/1900'), inplace=True)
df['DoB'] = pd.to_datetime(df['DoB']).apply(lambda x: x.date())
df['DoB'] = pd.to_datetime(df.DoB,format='%Y-%m-%d')
df

# %%
df['Year'] = df['DoB'].apply(lambda x:x.year)
df['Month'] = df['DoB'].apply(lambda x:x.month)
df['Day'] = df['DoB'].apply(lambda x:x.day)
df['day of week']=df['DoB'].dt.dayofweek # 5,6 are weekends
df

# %% [markdown]
# ## Convert Dictionary to DataFrame

# %%
ob3 = {
	"ID": 329256,
	"Name": 'Mr. James'
}

df = pd.DataFrame(ob3.items(), columns=['Key','Value'])
df.head()

# %%
import pandas as pd
from datetime import *
raw_data = {'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'], 
        'last_name': ['Miller', 'Jacobson', '', 'Milner', ''], 
        'DoB': ['1982/07/28', '', '1982-07-28', '', '29/07/1982'], 
        'preTestScore': [-999, -999, -999, 2, 1],
        'postTestScore': [2, 2, -999, 2, -999],
        'City':['Canberra','Canberra','Canberra','Canberra','Canberra']}
df = pd.DataFrame(raw_data, columns = ['first_name', 'last_name', 'DoB', 'preTestScore', 'postTestScore','City'])
df

# %% [markdown]
# ## Get Unique values from DataFrame column

# %%
import pandas as pd
df = pd.read_csv('http://bit.ly/kaggletrain', nrows=6)
df['Pclass'].unique()

# %%
uniqueValues = (df['Sex'].append(df['Cabin'])).unique()
uniqueValues

# %%
uniqueValues.tolist()

# %% [markdown]
# ## Column Transformation:

# %% [markdown]
# ### Using both OneHotEncoder &  SimpleImputer

# %% [markdown]
# Use ColumnTransformer to apply different preprocessing to different columns:
# * select from DataFrame columns by name
# * passthrough or drop unspecified columns

# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import make_column_transformer

ohe = OneHotEncoder()
imp = SimpleImputer()
oe = OrdinalEncoder(categories=[['first', 'second', 'third'], ['S', 'M', 'L', 'XL']])

df = pd.read_csv('http://bit.ly/kaggletrain', nrows=6)

cols = ['Fare', 'Embarked', 'Sex', 'Age']
X = df[cols]
X['size'] = ['S', 'S', 'L', 'XL','L','XL']
X['class'] = ['first', 'second', 'third','first', 'second', 'third']
X

# %%
ct = make_column_transformer(
    (ohe, ['Embarked', 'Sex']),  # apply OneHotEncoder to Embarked and Sex
    (imp, ['Age']),              # apply SimpleImputer to Age
    (oe, ['class','size']),
    remainder='passthrough')     # include remaining column (Fare) in the output

# column order: Embarked (3 columns), Sex (2 columns), Age (1 column), Fare (1 column)
print(ct.fit_transform(X))

# %% [markdown]
# You will notice in the code above I have used the categories argument of the OnHotEncoder function. This takes a list of all possible categories in each column as a list of lists. This produces one hot encoded columns for all categories even if data does not exist for that category in the column. The reason for doing this is that when using the ColumnTransformer function on new data. If it doesn’t contain the same categories in each feature then the array produced will not be the same shape as the data used to train the model, and you will get an error.

# %% [markdown]
# ### Diff. btw OneHotEncoder & OrdinalEncoder:

# %% [markdown]
# Two common ways to encode categorical features:
#
# * OneHotEncoder for unordered (nominal) data
# * OrdinalEncoder for ordered (ordinal) data

# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder

X = pd.DataFrame({'Shape':['square', 'square', 'oval', 'circle'],
                  'Class': ['third', 'first', 'second', 'third'],
                  'Size': ['S', 'S', 'L', 'XL']})
X

# %%
# left-to-right column order is alphabetical (circle, oval, square)
ohe = OneHotEncoder(sparse=False)
ohe.fit_transform(X[['Shape']])

# %%
# category ordering (within each feature) is defined by you
oe = OrdinalEncoder(categories=[['first', 'second', 'third'], ['S', 'M', 'L', 'XL']])
oe.fit_transform(X[['Class', 'Size']])

# %% [markdown]
# ## Parallel Processing in DataFrames

# %%
import vaex
import pandas as pd
import numpy as np
import modin.pandas as mpd

# %%
n_rows = 1000000
n_cols = 1000
df = pd.DataFrame(np.random.randint(0,100,size=(n_rows,n_cols)), columns=['col%d' % i for i in range(n_cols)])
df.head()
# Out:
#    col0  col1  col2  col3  col4  col5  col6  col7  col8  col9  ...  col990  \
# 0    59    49    57    69     1    36    89    48    28    77  ...      39
# 1    55    85    15    68    75    16    88     0    55    15  ...      53
# 2    24    87    92    10    13    52    86    19    98    85  ...      23
# 3    37    31    99    47    73    90     0    61    19    88  ...      83
# 4    41     9    33    34    48    11    13    99     7    59  ...      65
#
#    col991  col992  col993  col994  col995  col996  col997  col998  col999
# 0      50      91      64      73      71      97       2      78      42
# 1      35      92      25      64      58      33      84      73      34
# 2      86      55      70      82      24      19      92      78      20
# 3      85       2      27       7      71      21       7      58       1
# 4      21      38      38       9      87      24      40      34      28
#
# [5 rows x 1000 columns]

# %%
df.to_csv('./data/big_file.csv', index=False)

# %%
dv = vaex.from_csv('./data/big_file.csv', convert=True,chunk_size=5_000_000)

# %%
dv = vaex.open('./data/big_file.csv.hdf5')

# %%
suma = dv.col1.sum()
suma
# Out:
# array(49445642, dtype=int64)

# %%
suma1 = df.col1.sum()
suma1
# Out:
# 49445642

# %%
dv.plot1d(dv.col2,figsize=(14,7))

# %%
dv['col1_plus_col2'] = dv.col1+dv.col2
dv['col1_plus_col2']
# Out:
# Expression = col1_plus_col2
# Length: 1,000,000 dtype: int64 (column)
# ---------------------------------------
#      0  106
#      1  100
#      2  179
#      3  130
#      4   42
#     ...
# 999995  126
# 999996   46
# 999997  131
# 999998   39
# 999999   37

# %%
df['col1_plus_col2'] = df.col1+df.col2
df['col1_plus_col2']
# Out:
# 0         106
# 1         100
# 2         179
# 3         130
# 4          42
#          ...
# 999995    126
# 999996     46
# 999997    131
# 999998     39
# 999999     37
# Name: col1_plus_col2, Length: 1000000, dtype: int32

# %%
dvv = dv[dv.col1 >90]
dvv.head()
# Out:
#   #    col0    col1    col2    col3    col4    col5    col6    col7    col8    col9    col10    col11    col12    col13    col14    col15    col16    col17    col18    col19    col20    col21    col22    col23    col24    col25    col26    col27    col28    col29    col30    col31    col32    col33    col34    col35    col36    col37    col38    col39    col40    col41    col42    col43    col44    col45    col46    col47    col48    col49    col50    col51    col52    col53    col54    col55    col56    col57    col58    col59    col60    col61    col62    col63    col64    col65    col66    col67    col68    col69    col70    col71    col72    col73    col74    col75    col76    col77    col78    col79    col80    col81    col82    col83    col84    col85    col86    col87    col88    col89    col90    col91    col92    col93    col94    col95    col96    col97    col98    col99    col100    col101    col102    col103    col104    col105    col106    col107    col108    col109    c
# ...

# %%
dff = df[df.col1 >90]
dff.head()
# Out:
#     col0  col1  col2  col3  col4  col5  col6  col7  col8  col9  ...  col991  \
# 10    74    95    45    66    89    77    69    90    49    76  ...      13
# 12     9    96    84    44    30    41    47    79    80     3  ...      89
# 21    66    93    89    26    92    56    26    33    89    49  ...      16
# 40    88    99    14    33    41    39    25    61    20    93  ...      88
# 50    92    98    77     3    15    15     2     1    46     4  ...      96
#
#     col992  col993  col994  col995  col996  col997  col998  col999  \
# 10      81      51      57       2      95      69      41      84
# 12      84      86      26       6       9       4      92       5
# 21      70      58       2      94      76      46      80      42
# 40      49      59       4      22      38      72      38      13
# 50      44      86      80      74      32      15      28      79
#
#     col1_plus_col2
# 10             140
# 12             180
# 21             182
# 40             113
# ...

# %%
dv_group = dv.groupby(dv['col150'],agg=vaex.agg.sum(dv['col3']))
dv_group.head()
# Out:
# #    col150    col3_sum
# 0    83        493748
# 1    90        486066
# 2    68        489810
# 3    34        484014
# 4    72        492764
# ...  ...       ...
# 95   16        493857
# 96   2         487602
# 97   6         504012
# 98   14        498958
# 99   67        485517

# %% [markdown]
# # Generate a Unique Key for a table record

# %%
from datetime import datetime
from uuid import uuid4

# %%
x = datetime.now().strftime('%Y%m-%d%H-%M%S-') + str(uuid4())
x

# %% [markdown]
# # Extract E-mails from text

# %%
import re

# %%
text = """The E-Book looks amazing and I would like a copy of it, here is my e-mail id - xyz@gmail.com | 
        Hi, I am looking for a job in data science field, please send me the E-book and kindly suggest
        how to move forward, thanks - ab_c@gmail.com"""
re.findall(r"([\w.-]+@[\w.-]+)", text)

# %% [markdown]
# # Progress Bar

# %%
from tqdm import tqdm_notebook
k = 1

k = k+1
for outer_loop in tqdm_notebook(range(1,10), desc = 'outer_loop', leave = True):
    for inner_loop in tqdm_notebook(range(1,1000,1), desc = 'inner_loop', leave = False):
        k+=100

# %% [markdown]
# # Remove Emoji's from text

# %%
text= "Hi 😂! Have a nice weekend 💕👭"
preprocessed_text=text.encode('ascii', 'ignore').decode('ascii')

print("Raw tweet:",text)  #with emoji
print("Preprocessed tweet:",preprocessed_text) # no emoji

# %% [markdown]
# # Machine Learning

# %% [markdown]
# ## Exploratory Analysis:

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import missingno as msno

# %matplotlib inline
# %precision 3
np.set_printoptions(precision=3)
np.random.seed(0)

# %% [markdown]
# ### Import Data

# %%
colnames=['Age','WClass','Fnlwgt','Education','Education_N','Marital_status','Ocupation','Relationship','Race','Sex','Size','CapitalGain','CapitalLoss','HoursPerWeek','Country','IncomeRange'
]
data = pd.read_csv('data\incomedata.csv', header=None, names=colnames)
data.iloc[8:15]
# Out:
#      Age      WClass  Fnlwgt      Education  Education_N       Marital_status  \
# 8   31.0     Private   45781        Masters          NaN        Never-married
# 9   42.0     Private  159449      Bachelors          NaN   Married-civ-spouse
# 10  37.0     Private  280464   Some-college          NaN   Married-civ-spouse
# 11  30.0   State-gov  141297      Bachelors          NaN   Married-civ-spouse
# 12  23.0     Private  122272      Bachelors          NaN        Never-married
# 13  32.0     Private  205019     Assoc-acdm          NaN        Never-married
# 14  40.0     Private  121772      Assoc-voc          NaN   Married-civ-spouse
#
#            Ocupation    Relationship                 Race      Sex Size  \
# 8     Prof-specialty   Not-in-family                White   Female    S
# 9    Exec-managerial         Husband                White     Male    M
# 10   Exec-managerial         Husband                Black     Male    M
# ...

# %% [markdown]
# ### Missing values

# %%
from IPython.display import Image
Image("data/missingvalues.png")

# %% [markdown]
# #### Examine Target

# %%
data['IncomeRange'].value_counts()
# Out:
#  <=50K    24720
#  >50K      7841
# Name: IncomeRange, dtype: int64

# %% [markdown]
# #### All features

# %%
mis_val = data.isnull().sum()
mis_val
# Out:
# Age               25
# WClass             0
# Fnlwgt             0
# Education          0
# Education_N        7
# Marital_status     0
# Ocupation          0
# Relationship       0
# Race               0
# Sex                0
# Size               0
# CapitalGain        0
# CapitalLoss        0
# HoursPerWeek       0
# Country            0
# IncomeRange        0
# dtype: int64

# %%
# Percentage of missing values
mis_val_percent = 100 * data.isnull().sum() / len(data)
mis_val_percent
# Out:
# Age               0.076779
# WClass            0.000000
# Fnlwgt            0.000000
# Education         0.000000
# Education_N       0.021498
# Marital_status    0.000000
# Ocupation         0.000000
# Relationship      0.000000
# Race              0.000000
# Sex               0.000000
# Size              0.000000
# CapitalGain       0.000000
# CapitalLoss       0.000000
# HoursPerWeek      0.000000
# Country           0.000000
# IncomeRange       0.000000
# dtype: float64

# %%
# Make a table with the results
mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
# Rename the columns
mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values'})
# Sort the table by percentage of missing descending
mis_val_table_ren_columns = mis_val_table_ren_columns[
            mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1)
# Print some summary information
print ("Your selected dataframe has " + str(data.shape[1]) + " columns.\n"      
            "There are " + str(mis_val_table_ren_columns.shape[0]) +
              " columns that have missing values.")
mis_val_table_ren_columns
# Out:
# Your selected dataframe has 16 columns.
# There are 2 columns that have missing values.
#              Missing Values  % of Total Values
# Age                      25                0.1
# Education_N               7                0.0

# %% [markdown]
# #### Visualize Missing data

# %%
msno.bar(data)

# %%
msno.matrix(data)

# %%
#sorted by Age
sorted = data.sort_values('Age')
msno.matrix(sorted)

# %%
msno.heatmap(data)

# %%
msno.dendrogram(data)

# %% [markdown]
# #### Fill Missing values

# %% [markdown]
# ##### KNN Imputer

# %%
# pip install -U scikit-learn
from sklearn.impute import KNNImputer

knn_imputer = KNNImputer(n_neighbors=2, weights="uniform")
data['Age'] = knn_imputer.fit_transform(data[['Age']])

# %% [markdown]
# ##### MICE Imputer

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

mice_imputer = IterativeImputer()
data['Education_N'] = mice_imputer.fit_transform(data[['Education_N']])

# %%
data.iloc[8:15]
# Out:
#      Age      WClass  Fnlwgt      Education  Education_N       Marital_status  \
# 8   31.0     Private   45781        Masters          NaN        Never-married
# 9   42.0     Private  159449      Bachelors          NaN   Married-civ-spouse
# 10  37.0     Private  280464   Some-college          NaN   Married-civ-spouse
# 11  30.0   State-gov  141297      Bachelors          NaN   Married-civ-spouse
# 12  23.0     Private  122272      Bachelors          NaN        Never-married
# 13  32.0     Private  205019     Assoc-acdm          NaN        Never-married
# 14  40.0     Private  121772      Assoc-voc          NaN   Married-civ-spouse
#
#            Ocupation    Relationship                 Race      Sex Size  \
# 8     Prof-specialty   Not-in-family                White   Female    S
# 9    Exec-managerial         Husband                White     Male    M
# 10   Exec-managerial         Husband                Black     Male    M
# ...

# %% [markdown]
# ### Calculate PPS Score:

# %%
import ppscore as pps
pps_df = pps.matrix(data)

# %%
pps_df.round(2)

# %% [markdown]
# ### Change Column data type

# %%
data['CapitalGain'] = data['CapitalGain'].astype(np.float64)

# %% [markdown]
# ### Replace '?'

# %%
data.replace('?','Missing', inplace=True)
data.replace(' ?','Missing',inplace=True)

# %% [markdown]
# ### Binning:

# %%
bins = [0,30,50,75,np.inf]
names = ['LE_30','31_50','51_75','75+']
data['AgeRange'] = pd.cut(data['Age'], bins, labels=names)

# %% [markdown]
# ### Drop columns:

# %%
data.drop(['Fnlwgt','Education_N'],axis=1,inplace=True)
data.drop(['Age'],axis=1,inplace=True)

# %% [markdown]
# ### Column Names and Type:

# %%
data.info()

# %% [markdown]
# ### Seperate Numerical & Categorical data

# %%
cat_feature_mask = (data.dtypes==object)
cat_cols = data.columns[cat_feature_mask].tolist()

data_cat = data[cat_cols]
data_cat.head()

# %%
num_feature_mask = (data.dtypes!=object)
num_cols = data.columns[num_feature_mask].tolist()

data_num = data[num_cols]
data_num.head()

# %% [markdown]
# ### Analyse Numerical data:

# %%
data_num.shape

# %%
data_num.isnull().sum()

# %%
data_num.fillna(data_num.mean())

# %%
data_num.describe()

# %%
# Correlation:
corr = data_num.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)

# %%
# Scatter Matrix
pd.plotting.scatter_matrix(data_num, alpha=0.2, figsize=(10, 10))
plt.show()

# %%
# # OUTLIERS
# Q1 = data_num.quantile(0.25)
# Q3 = data_num.quantile(0.75)
# IQR = Q3 - Q1
  
# print('Before Outliers check, Row count is: ',len(data_num.index))
# df_o_n = data_num[~((data_num < (Q1 - 1.5 * IQR)) |(data_num > (Q3 + 1.5 * IQR))).any(axis=1)]
# print('After Outliers are removed, Row count is: ',len(data_num.index))

# %% [markdown]
# ### Join Numerical and Categorical data:

# %%
# Join Categorical and Numerical data
data_nc = data_num.join(data_cat)
data_nc.head()

# %%
pps_df = pps.matrix(data)
pps_df.round(2)

# %%
pps_df.round(2)

# %% [markdown]
# ## Template: Modelling (Traditional ML)

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestClassifier
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression,RidgeClassifierCV
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler,LabelEncoder
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from xgboost.sklearn import XGBClassifier
from prettytable import PrettyTable
from sklearn.preprocessing import FunctionTransformer
from sklearn.metrics import accuracy_score, classification_report, roc_curve, roc_auc_score, confusion_matrix
import eli5

# %% [markdown]
# ### Import Data

# %%
colnames=['Age','WClass','Fnlwgt','Education','Education_N','Marital_status','Ocupation','Relationship','Race','Sex','Size','CapitalGain','CapitalLoss','HoursPerWeek','Country','IncomeRange'
]
data = pd.read_csv('data\incomedata.csv', header=None, names=colnames)

# %%
data.head(5)

# %% [markdown]
# ### Data Wrangling:

# %% [markdown]
# #### Change Column data type

# %%
data['CapitalGain'] = data['CapitalGain'].astype(np.float64)

# %% [markdown]
# #### Replace '?'

# %%
data.replace('?','Missing', inplace=True)
data.replace(' ?','Missing',inplace=True)

# %% [markdown]
# #### Binning:

# %%
bins = [0,30,50,75,np.inf]
names = ['LE_30','31_50','51_75','75+']
data['AgeRange'] = pd.cut(data['Age'], bins, labels=names)

# %% [markdown]
# #### Drop columns:

# %%
data.drop(['Fnlwgt','Education_N'],axis=1,inplace=True)
data.drop(['Age'],axis=1,inplace=True)

# %% [markdown]
# #### Column Names and Type:

# %%
data.info()

# %% [markdown]
# ### Model Training

# %% [markdown]
# #### Seperate Class variable from the dataset

# %%
y = data['IncomeRange']
X = data.drop('IncomeRange', axis=1)

le = LabelEncoder()
le.fit(y)
y = le.transform(y)

# %% [markdown]
# #### Split into Train and Test dataset

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=.3, random_state=42)

# %% [markdown]
# #### Seperate Numerical and Categorical features

# %%
all_cols = X_train.columns
num_cols = X_train._get_numeric_data().columns.to_list()
cat_cols = list(set(all_cols) - set(num_cols))

# cat_feature_mask = (X_train.dtypes==object)
# cat_cols = X_train.columns[cat_feature_mask].tolist()
# num_feature_mask = (X_train.dtypes!=object)
# num_cols = X_train.columns[num_feature_mask].tolist()

# %% [markdown]
# #### Configure Pipeline:

# %%
uniqueValues = (X_train['Size'].unique().tolist(),
                X_train['AgeRange'].unique().tolist(),
#                 ['LE_30','31_50','51_75','75+'],
                X_train['Ocupation'].unique().tolist(),
                X_train['WClass'].unique().tolist(),
                X_train['Relationship'].unique().tolist(),
                X_train['Country'].unique().tolist(),
                X_train['Race'].unique().tolist(),
                X_train['Sex'].unique().tolist(),
                X_train['Education'].unique().tolist(),
                X_train['Marital_status'].unique().tolist()
               )

# %%
def get_custom(df):
    df.replace('?', np.nan, inplace=True)
    df.replace(' ?', np.nan, inplace=True)
    
#     bins = [0,30,50,75,np.inf]
#     names = ['LE_30','31_50','51_75','75+']
#     df['AgeRange'] = pd.cut(df['Age'], bins, labels=names)
    
#     df.drop(['Fnlwgt','Education_N'],axis=1,inplace=True)
#     df.drop(['Age'],axis=1,inplace=True)    
    
    return df

get_custom = FunctionTransformer(get_custom, validate=False)

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
    ('onehot', OneHotEncoder(sparse=False,categories=uniqueValues,handle_unknown='ignore'))])

numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler(copy=False))])

custom_transformer = Pipeline(steps=[('custom', get_custom)])

preprocessor = ColumnTransformer([
#     ("custom", custom_transformer, all_cols),
    ("numerical", numeric_transformer, num_cols),
    ("categorical", categorical_transformer, cat_cols)])

# %% [markdown]
# #### Instantiate Models

# %%
# Logistic Regression
lr_model = Pipeline([("preprocessor", preprocessor), 
                     ("model", LogisticRegression(class_weight="balanced", solver="liblinear", random_state=42))])

# Decision Tree
dt_model = Pipeline([("preprocessor", preprocessor), 
                     ("model", DecisionTreeClassifier(class_weight="balanced"))])

# Random Forest
rf_model = Pipeline([("preprocessor", preprocessor), 
                     ("model", RandomForestClassifier(class_weight="balanced", n_estimators=100, n_jobs=-1))])

# SVM
svm_model = Pipeline([("preprocessor", preprocessor), 
                      ("model", SVC(kernel='linear', C = 1.0))])

# XGBoost
xgb_model = Pipeline([("preprocessor", preprocessor), 
                      ("model", XGBClassifier(scale_pos_weight=(1 - y_train.mean()), n_jobs=-1))])

# RidgeCV
rdgcv_model = Pipeline([("preprocessor", preprocessor), 
                     ("model", RidgeClassifierCV())])

pt = PrettyTable(["Algorithm", "Accuracy", "Precision", "Recall", "F1 Score", "R2", "AUC Score"], sortby="AUC Score",reversesort=True)
pt.clear_rows()
print(pt)

# %% [markdown]
# #### Train

# %%
n_components = []

params_grid = [{
"model__C": [1, 1.3, 1.5]
}]

def algo_eval(algo,gs,mdl,X_train, y_train, X_test,y_test):
    gs.fit(X_train, y_train)
    mdl.set_params(**gs.best_params_)
    mdl.fit(X_train, y_train)
    y_pred = mdl.predict(X_test)

    po   = classification_report(y_test, y_pred,output_dict=True)['weighted avg']['precision']
    ao   = accuracy_score(y_test, y_pred)
    ro   = classification_report(y_test, y_pred,output_dict=True)['weighted avg']['recall']
    f1o  = classification_report(y_test, y_pred,output_dict=True)['weighted avg']['f1-score']
    r2o  = mdl.score(X_test, y_pred)
    auco = roc_auc_score(y_test, y_pred)
    mdl = None
    return [algo, ao,po,ro,f1o,r2o,auco]

# %% [markdown]
# ##### Logistic Regression

# %%
gs = GridSearchCV(lr_model, param_grid = params_grid, n_jobs=-1, cv=10, refit='AUC', scoring='roc_auc',iid=True)
algo, ao, po, ro, f1o, r2o, auco = algo_eval('LogReg2',gs,lr_model,X_train, y_train, X_test,y_test)
pt.add_row([algo, "%.2f" % ao, "%.2f" % po, "%.2f" % ro, "%.2f" % f1o, "%.2f" % r2o, "%.2f" % auco])

# %% [markdown]
# ##### Decision Tree

# %%
gs = GridSearchCV(dt_model, {"model__max_depth": [3, 5, 7],"model__min_samples_split": [2, 5]},n_jobs=-1, cv=5, refit='AUC', scoring='roc_auc',iid=True)
algo, ao, po, ro, f1o, r2o, auco = algo_eval('DecisionTree2',gs,dt_model,X_train, y_train, X_test,y_test)
pt.add_row([algo, "%.2f" % ao, "%.2f" % po, "%.2f" % ro, "%.2f" % f1o, "%.2f" % r2o, "%.2f" % auco])

# %% [markdown]
# ##### Random Forest

# %%
gs = GridSearchCV(rf_model, {"model__max_depth": [10, 15],"model__min_samples_split": [5, 10]},n_jobs=-1, cv=5, refit='AUC', scoring='roc_auc',iid=True)
algo, ao, po, ro, f1o, r2o, auco = algo_eval('RandomForest2',gs,rf_model,X_train, y_train, X_test,y_test)
pt.add_row([algo, "%.2f" % ao, "%.2f" % po, "%.2f" % ro, "%.2f" % f1o, "%.2f" % r2o, "%.2f" % auco])

# %% [markdown]
# ##### XGBoost

# %%
gs_o = GridSearchCV(xgb_model, {"model__max_depth": [5, 10],"model__min_child_weight": [5, 10],"model__n_estimators": [25]},
                  n_jobs=-1, cv=5, refit='AUC', scoring='roc_auc',iid=True)
algo, ao, po, ro, f1o, r2o, auco = algo_eval('XGBoost2',gs,xgb_model,X_train, y_train, X_test,y_test)
pt.add_row([algo, "%.2f" % ao, "%.2f" % po, "%.2f" % ro, "%.2f" % f1o, "%.2f" % r2o, "%.2f" % auco])

# %% [markdown]
# ##### SVM

# %%
# gs = GridSearchCV(svm_model, param_grid = params_grid,n_jobs=-1, cv=5, refit='AUC', scoring='roc_auc',iid=True)
# gs.fit(X_train, y_train)
# svm_model.set_params(**gs.best_params_)
# svm_model.fit(X_train, y_train)
# y_pred = svm_model.predict(X_test)

# po   = classification_report(y_test, y_pred,output_dict=True)['weighted avg']['precision']
# ao   = accuracy_score(y_test, y_pred)
# ro   = classification_report(y_test, y_pred,output_dict=True)['weighted avg']['recall']
# f1o  = classification_report(y_test, y_pred,output_dict=True)['weighted avg']['f1-score']
# r2o  = svm_model.score(X_test, y_pred)
# auco = roc_auc_score(y_test, y_pred)

# pt.add_row(["SVM", "%.2f" % ao, "%.2f" % po, "%.2f" % ro, "%.2f" % f1o, "%.2f" % r2o, "%.2f" % auco])

# %% [markdown]
# ##### RidgeClassifierCV

# %%
rdgcv_model.fit(X_train, y_train)
y_pred = rdgcv_model.predict(X_test)

po   = classification_report(y_test, y_pred,output_dict=True)['weighted avg']['precision']
ao   = accuracy_score(y_test, y_pred)
ro   = classification_report(y_test, y_pred,output_dict=True)['weighted avg']['recall']
f1o  = classification_report(y_test, y_pred,output_dict=True)['weighted avg']['f1-score']
r2o  = rdgcv_model.score(X_test, y_pred)
auco = roc_auc_score(y_test, y_pred)

pt.add_row(["RidgeCV", "%.2f" % ao, "%.2f" % po, "%.2f" % ro, "%.2f" % f1o, "%.2f" % r2o, "%.2f" % auco])

# %% [markdown]
# ### Select Best Model:

# %%
print(pt)

# %%
lr_bestmodel = lr_model

# %% [markdown]
# ### Model Testing:

# %%
# Refit Best Model and Predict:
lr_bestmodel.fit(X_train, y_train)
y_pred = lr_bestmodel.predict(X_test)
print('Best Model ROC_AUC:',roc_auc_score(y_test, y_pred))
# Download the results:
res = pd.DataFrame(y_pred)
res.index = X_test.index
res.columns = ["prediction"]
df = X_test.join(res)
# df.to_csv("data\mergedprediction_results.csv")
df.head()

# %% [markdown]
# ### Model Explainability:

# %% [markdown]
# #### Global:

# %%
preprocessor = lr_bestmodel.named_steps["preprocessor"]
ohe_categories = preprocessor.named_transformers_["categorical"]["onehot"].categories_
new_ohe_features = [f"{col}__{val}" for col, vals in zip(cat_cols, ohe_categories) for val in vals]
all_features = num_cols + new_ohe_features
eli5.show_weights(lr_bestmodel.named_steps["model"], feature_names=all_features, top=20)

# %%
# Convert to Dataframe
eli5_df = eli5.explain_weights_df(lr_bestmodel.named_steps["model"], feature_names=all_features, top=20)
eli5_df['weight'] = eli5_df['weight'] * 100
eli5_df.head()

# %% [markdown]
# #### Local

# %%
# Row 4 details:
i=5
eli5.explain_prediction_df(lr_bestmodel.named_steps["model"], 
                     lr_bestmodel.named_steps["preprocessor"].transform(X_test)[i],
                     feature_names=all_features)

# %% [markdown]
# ## TimeSeries Analysis:

# %% [markdown]
# ### Import Libraries

# %%
import warnings
import statsmodels.api as sm 
import pandas as pd          
import numpy as np
import matplotlib.pyplot as plt

from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
from sklearn.metrics import mean_squared_error
from matplotlib.pylab import rcParams
from math import sqrt
from datetime import datetime
# %matplotlib inline 
warnings.filterwarnings('ignore')
# Out:
# C:\Users\I054497\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ### Import Data

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv'
data = pd.read_csv(url)
data.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  5/31/20  6/1/20  6/2/20  6/3/20  6/4/20  \
# 0        0        0        0  ...    15205   15750   16509   17267   18054
# 1        0        0        0  ...     1137    1143    1164    1184    1197
# 2        0        0        0  ...     9394    9513    9626    9733    9831
# 3        0        0        0  ...      764     765     844     851     852
# 4        0        0        0  ...       86      86      86      86      86
#
#    6/5/20  6/6/20  6/7/20  6/8/20  6/9/20
# ...

# %% [markdown]
# ### Data Wrangling

# %% [markdown]
# #### Data formatting

# %%
df = data[data['Country/Region'].isin(['US'])]
df.drop(['Province/State','Country/Region','Lat','Long'], axis=1,inplace=True)

df = df.stack().reset_index()
df.rename(columns={'level_0': 'row', 'level_1': 'date', 0:'casesasondate'}, inplace=True)

df['date'] = pd.to_datetime(df['date'], format="%m/%d/%y")
df.set_index('date', inplace=True)

df['totalCases'] = df['casesasondate'].diff().fillna(1)
df['totalCases']=df['totalCases'].astype(int)
df.drop(['casesasondate','row'],axis=1,inplace=True)

df.head()
# Out:
#             totalCases
# date
# 2020-01-22           1
# 2020-01-23           0
# 2020-01-24           1
# 2020-01-25           0
# 2020-01-26           3

# %% [markdown]
# #### Missing values

# %%
# Interpolate using the linear method
df.interpolate(limit_direction="both",inplace=True)

# %% [markdown]
# ### Train Test split

# %%
df.plot(figsize=(15,5), title= 'Since January', fontsize=14)

# %%
train = df['2020-03-01':'2020-04-30']
test = df['2020-05-01':]

# %% [markdown]
# ### Test Stationarity

# %%
#Ho: It is non stationary
#H1: It is stationary

def adfuller_test(sales):
    result=adfuller(sales)
    labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations Used']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )
    if result[1] <= 0.05:
        print("strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data has no unit root and is stationary")
    else:
        print("weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary ")

# %%
def test_stationarity(timeseries):
    rolmean = timeseries.rolling(window=12).mean()
    rolstd = timeseries.rolling(window=12).std()

    #Plot rolling statistics:
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
    #Perform Dickey-Fuller test:
    print('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)

# %%
adfuller_test(train['totalCases'])
# Out:
# ADF Test Statistic : -1.7541640920850592
# p-value : 0.4034434574134422
# #Lags Used : 11
# Number of Observations Used : 49
# weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary

# %%
adfuller_test(np.log(train['totalCases']))
# Out:
# ADF Test Statistic : -2.9693310487909845
# p-value : 0.03785945963097739
# #Lags Used : 11
# Number of Observations Used : 49
# strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data has no unit root and is stationary

# %%
rcParams['figure.figsize'] = 20,10
test_stationarity(np.log(train['totalCases']))
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -2.969331
# p-value                         0.037859
# #Lags Used                     11.000000
# Number of Observations Used    49.000000
# Critical Value (1%)            -3.571472
# Critical Value (5%)            -2.922629
# Critical Value (10%)           -2.599336
# dtype: float64

# %%
rcParams['figure.figsize'] = 20,10
test_stationarity(train['totalCases'])
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -1.754164
# p-value                         0.403443
# #Lags Used                     11.000000
# Number of Observations Used    49.000000
# Critical Value (1%)            -3.571472
# Critical Value (5%)            -2.922629
# Critical Value (10%)           -2.599336
# dtype: float64

# %%
train_log = np.log(train['totalCases'])
train_log.plot()

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(train_log,lags=40,ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(train_log,lags=40,ax=ax2)

# %% [markdown]
# ### Find Best Parameters - p,d,q

# %%
import warnings
from pandas import read_csv
from pandas import datetime
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error

# evaluate an ARIMA model for a given order (p,d,q)
def evaluate_arima_model(X, arima_order):
	# prepare training dataset
	train_size = int(len(X) * 0.66)
	train, test = X[0:train_size], X[train_size:]
	history = [x for x in train]
	# make predictions
	predictions = list()
	for t in range(len(test)):
		model = ARIMA(history, order=arima_order)
		model_fit = model.fit(disp=0)
		yhat = model_fit.forecast()[0]
		predictions.append(yhat)
		history.append(test[t])
	# calculate out of sample error
	error = mean_squared_error(test, predictions)
	return error

# evaluate combinations of p, d and q values for an ARIMA model
def evaluate_models(dataset, p_values, d_values, q_values):
	dataset = dataset.astype('float32')
	best_score, best_cfg = float("inf"), None
	for p in p_values:
		for d in d_values:
			for q in q_values:
				order = (p,d,q)
				try:
					mse = evaluate_arima_model(dataset, order)
					if mse < best_score:
						best_score, best_cfg = mse, order
					print('ARIMA%s MSE=%.3f' % (order,mse))
				except:
					continue
	print('Best ARIMA%s MSE=%.3f' % (best_cfg, best_score))

# %%
series= train['totalCases']
# evaluate parameters
p_values = [0, 1, 2, 4, 6]
d_values = range(0, 3)
q_values = range(0, 3)
warnings.filterwarnings("ignore")
evaluate_models(np.log(series).values, p_values, d_values, q_values)
# Out:
# ARIMA(0, 0, 0) MSE=4.474
# ARIMA(0, 0, 1) MSE=1.397
# ARIMA(0, 0, 2) MSE=0.566
# ARIMA(0, 1, 0) MSE=0.048
# ARIMA(0, 1, 1) MSE=0.086
# ARIMA(0, 1, 2) MSE=0.077
# ARIMA(0, 2, 0) MSE=0.021
# ARIMA(0, 2, 1) MSE=0.023
# ARIMA(1, 0, 0) MSE=0.013
# ARIMA(1, 0, 1) MSE=0.013
# ARIMA(1, 0, 2) MSE=0.029
# ARIMA(1, 1, 0) MSE=0.084
# ARIMA(1, 1, 1) MSE=0.090
# ARIMA(1, 2, 0) MSE=0.023
# ARIMA(1, 2, 1) MSE=0.038
# ARIMA(2, 0, 0) MSE=0.014
# ARIMA(2, 0, 1) MSE=0.014
# ARIMA(2, 0, 2) MSE=0.079
# ARIMA(2, 1, 0) MSE=0.102
# ARIMA(2, 1, 1) MSE=0.091
# ARIMA(2, 2, 0) MSE=0.037
# ARIMA(2, 2, 1) MSE=0.060
# ARIMA(2, 2, 2) MSE=0.051
# ARIMA(4, 0, 0) MSE=0.032
# ARIMA(4, 0, 1) MSE=0.080
# ARIMA(4, 1, 0) MSE=0.051
# ARIMA(4, 2, 0) MSE=0.047
# ARIMA(4, 2, 1) MSE=0.053
# ARIMA(6, 0, 0) MSE=0.044
# ARIMA(6, 0, 1) MSE=0.078
# ARIMA(6, 1, 0) MSE=0.044
# ARIMA(6, 1, 1) MSE=0.034
# ARIMA(6, 2, 0) MSE=0.041
# ARIMA(6, 2, 1) MSE=0.051
# Best ARIMA(1, 0, 0) MSE=0.013

# %% [markdown]
# ### Model Training

# %%
model=ARIMA(train_log,order=(1,0,1))
model_fit=model.fit()

# %%
test_log = np.log(test['totalCases'])
predictions = model_fit.predict(start="2020-05-01", end="2020-05-23", dynamic=True)

# %%
plt.figure(figsize=(16,8)) 
plt.plot(np.exp(train_log), label='Train') 
plt.plot(np.exp(test_log), label='Test') 
plt.plot(np.exp(predictions), label='ARIMA') 
plt.legend(loc='best') 
plt.show()

# %%
for i in range(0,20):
    try:
            y_hat_avg = test.copy() 
            fit1 = sm.tsa.statespace.SARIMAX(train_log, order=(1, 0, 1),seasonal_order=(1, 0, 1,i)).fit()
            y_hat_avg['SARIMA'] = fit1.predict(start="2020-05-01", end="2020-05-30", dynamic=True)
            error = mean_squared_error(test['totalCases'], np.exp(y_hat_avg['SARIMA']))
            print(i,error)
    except:
        continue

# %% [markdown]
# ### Model Prediction

# %%
y_hat_avg = test.copy() 
fit1 = sm.tsa.statespace.SARIMAX(train_log, order=(1, 0, 1),seasonal_order=(1, 0, 1,7)).fit() 
y_hat_avg['SARIMA'] = fit1.predict(start="2020-05-01", end="2020-06-09", dynamic=True)
prediction = np.exp(y_hat_avg['SARIMA'])
error = mean_squared_error(test['totalCases'], prediction)
error
# Out:
# 13829066.957807034

# %%
plt.figure(figsize=(16,4)) 
plt.plot(train['totalCases'], label='Training') 
plt.plot(test['totalCases'], label='Validation') 
plt.plot(np.exp(y_hat_avg['SARIMA']), label='Predicted') 
plt.legend(loc='best') 
plt.show()

# %% [markdown]
# ### Forecasting

# %%
predictions = fit1.predict(start="2020-06-01", end="2020-09-30", dynamic=True) 
result_df = pd.DataFrame(predictions)
result_df.reset_index(inplace=True)
result_df.columns = ['Date','Prediction']
result_df['Prediction'] = np.exp(result_df['Prediction'])
result_df['Predictions'] = result_df['Prediction']
result_df['Predictions'] = result_df['Predictions'].astype(int)
result_df['Ventilators Required'] = result_df['Predictions'] * 0.23
result_df['Ventilators Required'] = result_df['Ventilators Required'].astype(int)

# %%
plt.figure(figsize=(16,8)) 
plt.plot(train['totalCases'], label='Training') 
plt.plot(test['totalCases'], label='Validation') 
plt.plot(np.exp(y_hat_avg['SARIMA']), label='Predicted')
plt.plot(predictions, label='Forecast') 
plt.legend(loc='best') 
plt.show()

# %%
result_df
# Out:
#           Date    Prediction  Predictions  Ventilators Required
# 0   2020-06-01  16395.646770        16395                  3770
# 1   2020-06-02  16347.038276        16347                  3759
# 2   2020-06-03  16290.555229        16290                  3746
# 3   2020-06-04  16258.028241        16258                  3739
# 4   2020-06-05  16198.672287        16198                  3725
# ..         ...           ...          ...                   ...
# 117 2020-09-26    953.427835          953                   219
# 118 2020-09-27    931.276132          931                   214
# 119 2020-09-28    909.984478          909                   209
# 120 2020-09-29    890.316712          890                   204
# 121 2020-09-30    871.126099          871                   200
#
# [122 rows x 4 columns]

# %% [markdown]
# ## Document Similarity

# %% [markdown]
# https://medium.com/@adriensieg/text-similarities-da019229c894

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import re
from scipy.spatial import distance
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer
from nltk.tokenize import word_tokenize, sent_tokenize

# %% [markdown]
# ### Import Data

# %%
lem = WordNetLemmatizer()
stop_words = set(stopwords.words("english"))
stop_words = set(map(str.strip, open('./data/localstopwords.txt')))
gloveFile = "./data/glove.6B.50d.txt"

# %%
projects = pd.read_csv('./data/projects_NBRA_bvr.csv')
projects = projects[['Project Number','Keywords','Description','Requirement']]
projects.fillna('', inplace=True)

challenges = pd.read_csv('./data/NBRA_Qualtrics_data.csv')
challenges = challenges[['Response ID','Local Government Area (LGA):','List any challenges identified in the meeting:']]
challenges.fillna('', inplace=True)

# %% [markdown]
# ### Local Functions

# %%
def preprocess(str1):
    str1 = re.sub("[^a-zA-Z]", " ", str1)    
    tokens1 = sent_tokenize(str1)    
    file_docs1 = []

    for line in tokens1:
        file_docs1.append(line)
        
    gen_docs1 = [[w.lower() for w in word_tokenize(text)] for text in file_docs1]    
    gen_docs11 = []
    for line in gen_docs1:
        filtered_sentence = [w for w in line if not w in stop_words]
        gen_docs11.append(filtered_sentence)
        
    fs1 = []    
    for gen_doc in gen_docs11:
        for w in gen_doc:
            fs1.append(lem.lemmatize(w))  
            
    fs1_str = ' '.join([str(elem) for elem in fs1])
    
    return [fs1,fs1_str]

# %%
def loadGloveModel(gloveFile):
    print ("Loading Glove Model")
    with open(gloveFile, encoding="utf8" ) as f:
        content = f.readlines()
    model = {}
    for line in content:
        splitLine = line.split()
        word = splitLine[0]
        embedding = np.array([float(val) for val in splitLine[1:]])
        model[word] = embedding
    print ("Done.",len(model)," words loaded!")
    return model

# %%
def jaccard_similarity(query, document):
    intersection = set(query).intersection(set(document))
    union = set(query).union(set(document))
    return (len(intersection)/len(union))*100

# %%
def cosine_distance_wordembedding_method(s1, s2):
    try:
        vector_1 = np.mean([model[word] for word in preprocess(s1)[0]],axis=0)
        vector_2 = np.mean([model[word] for word in preprocess(s2)[0]],axis=0)
        cosine = distance.cosine(vector_1, vector_2)
    except:
        cosine = 1
        
    return round((1-cosine)*100,2)

# %%
def cosine_distance_countvectorizer_method(s1, s2):
    s1 = re.sub("[^a-zA-Z]", " ", s1)
    s2 = re.sub("[^a-zA-Z]", " ", s2)
    
    allsentences = [s1 , s2]
    vectorizer = CountVectorizer()
    all_sentences_to_vector = vectorizer.fit_transform(allsentences)
    text_to_vector_v1 = all_sentences_to_vector.toarray()[0].tolist()
    text_to_vector_v2 = all_sentences_to_vector.toarray()[1].tolist()
    cosine = distance.cosine(text_to_vector_v1, text_to_vector_v2)
    return round((1-cosine)*100,2)

# %%
def formatted_jaccard_similarity(str1,str2):
    
    fs1_str = preprocess(str1)[1]
    fs2_str = preprocess(str2)[1]
    
    return jaccard_similarity(fs1_str,fs2_str)

# %% [markdown]
# ### Evaluate Similarity

# %%
model = loadGloveModel(gloveFile)
# Out:
# Loading Glove Model
# Done. 400000  words loaded!

# %%
percentage_of_similarity_cdcv = []
percentage_of_similarity_cdwe = []
percentage_of_similarity_js = []
challenge_id = []
challenge_lga = []
challenge_txt = []
project_id = []
project_txt = []

# %%
# y = 0
for index, challenge in challenges.iterrows():
#     y = y + 1
#     if y > 1:
#         break
    str1 = challenge[2]
#     z = 0
    for index2, project in projects.iterrows():
#         z = z + 1
#         if z > 1:
#             break
        str2 = project[1].replace(',', '') + project[2]+ project[3]
        
        result_js = formatted_jaccard_similarity(str1,str2)
        result_cdcv = cosine_distance_countvectorizer_method(str1,str2)
        result_cdwe = cosine_distance_wordembedding_method(str1,str2)
        
        challenge_id.append(challenge[0])
        challenge_lga.append(challenge[1])
        challenge_txt.append(challenge[2])        
        project_id.append(project[0])
#         project_txt.append(project[2])
        project_txt.append(str2)
        percentage_of_similarity_cdcv.append(result_cdcv)
        percentage_of_similarity_js.append(result_js)
        percentage_of_similarity_cdwe.append(result_cdwe)
# Out:
# C:\Users\I054497\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\spatial\distance.py:720: RuntimeWarning: invalid value encountered in double_scalars
#   dist = 1.0 - uv / np.sqrt(uu * vv)
# C:\Users\I054497\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\I054497\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
result = {'Challenge_ID': challenge_id,
          'Challenge_LGA': challenge_lga,
          'Challenge_text': challenge_txt,
          'Project_ID': project_id,
          'Project_text': project_txt,
          'CosineDistCVScore': percentage_of_similarity_cdcv,
          'CosineDistWEScore': percentage_of_similarity_cdwe,
          'JaccardSimilarityScore': percentage_of_similarity_js}
result_df = pd.DataFrame(result)
result_df.set_index('Challenge_ID', inplace=True)
# result_df.to_csv('final_result.csv')
result_df.head()
# Out:
#                       Challenge_LGA  \
# Challenge_ID
# R_cRMovmDzAmaNPy5  NSW - Cumberland
# R_cRMovmDzAmaNPy5  NSW - Cumberland
# R_cRMovmDzAmaNPy5  NSW - Cumberland
# R_cRMovmDzAmaNPy5  NSW - Cumberland
# R_cRMovmDzAmaNPy5  NSW - Cumberland
#
#                                                       Challenge_text  \
# Challenge_ID
# R_cRMovmDzAmaNPy5  We need to establish more work. This will be i...
# R_cRMovmDzAmaNPy5  We need to establish more work. This will be i...
# R_cRMovmDzAmaNPy5  We need to establish more work. This will be i...
# R_cRMovmDzAmaNPy5  We need to establish more work. This will be i...
# R_cRMovmDzAmaNPy5  We need to establish more work. This will be i...
#
#                     Project_ID  \
# Challenge_ID
# R_cRMovmDzAmaNPy5    Project 1
# R_cRMovmDzAmaNPy5    Project 2
# R_cRMovmDzAmaNPy5  Project 2.1
# R_cRMovmDzAmaNPy5  Project 2.2
# R_cRMovmDzAmaNPy5  Project 2.3
#
#                                                         Project_text  \
# ...

# %%
str1 = 'President greets the press in Chicago. They are very good'
str2 = 'Obama speaks in Illinois'
print('Jaccard Similarity score:', jaccard_similarity(str1,str2))
print('Formatted Jaccard Similarity score:',formatted_jaccard_similarity(str1,str2))
print('Cosine distance CV score:', cosine_distance_countvectorizer_method(str1 , str2))
print('Cosine distance WE score:', cosine_distance_wordembedding_method(str1 , str2))
# Out:
# Jaccard Similarity score: 30.76923076923077
# Formatted Jaccard Similarity score: 44.44444444444444
# Cosine distance CV score: 15.81
# Cosine distance WE score: 75.3

# %%
# def jensen_shannon(query, matrix):
#     """
#     This function implements a Jensen-Shannon similarity
#     between the input query (an LDA topic distribution for a document)
#     and the entire corpus of topic distributions.
#     It returns an array of length M where M is the number of documents in the corpus
#     """
#     # lets keep with the p,q notation above
#     p = query[None,:].T # take transpose
#     q = matrix.T # transpose matrix
#     m = 0.5*(p + q)
#     return np.sqrt(0.5*(entropy(p,m) + entropy(q,m)))

# def get_most_similar_documents(query,matrix,k=10):
#     """
#     This function implements the Jensen-Shannon distance above
#     and retruns the top k indices of the smallest jensen shannon distances
#     """
#     sims = jensen_shannon(query,matrix) # list of jensen shannon distances
#     return sims.argsort()[:k] # the top k positional index of the smallest Jensen Shannon distances

# %% [markdown]
# ## Multivariate Text Classification

# %% [markdown]
# ### Import Libraries

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_files

# %% [markdown]
# ### Import Data

# %%
DATA_DIR = "./data/bbc/"
data = load_files(DATA_DIR, encoding="utf-8", decode_error="replace")

# %%
# calculate count of each category
labels, counts = np.unique(data.target, return_counts=True)
# convert data.target_names to np array for fancy indexing
labels_str = np.array(data.target_names)[labels]
print(dict(zip(labels_str, counts)))
# Out:
# {'business': 510, 'entertainment': 386, 'politics': 417, 'sport': 511, 'tech': 401}

# %% [markdown]
# ### Split Data

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data.data, data.target)
list(t[:80] for t in X_train[:10])
# Out:
# ["Captains lining up for Aid match\n\nIreland's Brian O'Driscoll is one of four Six ",
#  'Jones happy with Henson heroics\n\nWales fly-half Stephen Jones admitted he was ha',
#  "Hanks greeted at wintry premiere\n\nHollywood star Tom Hanks was in London's Leice",
#  'ECB holds rates amid growth fears\n\nThe European Central Bank has left its key in',
#  "Indonesia 'declines debt freeze'\n\nIndonesia no longer needs the debt freeze offe",
#  'Europe backs digital TV lifestyle\n\nHow people receive their digital entertainmen',
#  'QPR keeper Day heads for Preston\n\nQueens Park Rangers keeper Chris Day is set to',
#  'Mobile multimedia slow to catch on\n\nThere is no doubt that mobile phones sportin',
#  'Japan turns to beer alternatives\n\nJapanese brewers are increasingly making money',
#  'Defection timed to hit tax pledge\n\nWith impeccable and precisely-calculated timi']

# %% [markdown]
# ### Model Training

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.model_selection import cross_val_score
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report, accuracy_score

# start with the classic
# with either pure counts or tfidf features
mnb = Pipeline([
        ("count vectorizer", CountVectorizer(stop_words="english", max_features=3000)),
        ("mnb", MultinomialNB())
    ])
mnb_tfidf = Pipeline([
        ("tfidf_vectorizer", TfidfVectorizer(stop_words="english", max_features=3000)),
        ("mnb", MultinomialNB())
    ])

sgd = Pipeline([
        ("count vectorizer", CountVectorizer(stop_words="english", max_features=3000)),
        ("sgd", SGDClassifier(loss="modified_huber"))
    ])
sgd_tfidf = Pipeline([
        ("tfidf_vectorizer", TfidfVectorizer(stop_words="english", max_features=3000)),
        ("sgd", SGDClassifier(loss="modified_huber"))
    ])
 
svc = Pipeline([
        ("count_vectorizer", CountVectorizer(stop_words="english", max_features=3000)),
        ("linear svc", SVC(kernel="linear"))
    ])
svc_tfidf = Pipeline([
        ("tfidf_vectorizer", TfidfVectorizer(stop_words="english", max_features=3000)),
        ("linear svc", SVC(kernel="linear"))
    ])
   
all_models = [
    ("mnb", mnb),
    ("mnb_tfidf", mnb_tfidf),    
    ("sgd", sgd),
    ("sgd_tfidf", sgd_tfidf),
    ("svc", svc),
    ("svc_tfidf", svc_tfidf),
    ]
 
unsorted_scores = [(name, cross_val_score(model, X_train, y_train, cv=2).mean()) for name, model in all_models]
scores = sorted(unsorted_scores, key=lambda x: -x[1])
print(scores)
# Out:
# [('mnb_tfidf', 0.9712230215827338), ('svc_tfidf', 0.9706235011990407), ('mnb', 0.9688249400479616), ('sgd_tfidf', 0.9622302158273381), ('sgd', 0.9592326139088729), ('svc', 0.9550359712230216)]

# %% [markdown]
# ### Model Testing

# %%
model = svc_tfidf
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print(accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 0.9802513464991023
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97       131
#            1       0.97      0.99      0.98        93
#            2       0.96      0.96      0.96        97
#            3       0.99      1.00      1.00       139
#            4       1.00      0.98      0.99        97
#
#     accuracy                           0.98       557
#    macro avg       0.98      0.98      0.98       557
# weighted avg       0.98      0.98      0.98       557
